# %%
import pandas as pd
import scipy as sp
import numpy as np
import dat
import matplotlib.pyplot as plt

# %%
def mahalanobis(x=None, data=None, cov=None):
    """Compute the Mahalanobis Distance between each row of x and the data  
    x    : vector or matrix of data with, say, p columns.
    data : ndarray of the distribution from which Mahalanobis distance of each observation of x is to be computed.
    cov  : covariance matrix (p x p) of the distribution. If None, will be computed from data.
    """
    #print('x',x)
    #print('data',data)
    x_minus_mu = x - np.mean(data)
    if not cov:
        cov = np.cov(data.values.T)
    inv_covmat = np.linalg.inv(cov)
    left_term = np.dot(x_minus_mu, inv_covmat)
    mahal = np.dot(left_term, x_minus_mu.T)
    return mahal.diagonal()

# %%
datik = dat.Samples(10)

# %%
datx = dat.Samples(10)

# %%
Results = []

for  i in range(100):
    X = datx.sample(5)
    res = mahalanobis(x=X, data= datik).tolist()
    Results.extend(res)
    '''if i == 0:
        Results = res
    else:
        a = np.concatenate((Results,res), axis=0)'''
    i = i+1

# %%
plt.hist(Results)
plt.title('data = N(10,0), vector = N(10,0)')
# Out:
# Text(0.5, 1.0, 'data = N(10,0), vector = N(10,0)')

# %%
plt.hist(Results)
plt.title('data = N(10,0), vector = N(0,0)')
# Out:
# Text(0.5, 1.0, 'data = N(10,0), vector = N(0,0)')

# %%
plt.hist(Results)
plt.title('data = N(0,0), vector = N(40,0)')
# Out:
# Text(0.5, 1.0, 'data = N(0,0), vector = N(40,0)')

# %%
plt.hist(Results)
plt.title('data = N(0,0), vector = N(30,0)')
# Out:
# Text(0.5, 1.0, 'data = N(0,0), vector = N(30,0)')

# %%
plt.hist(Results)
plt.title('data = N(0,0), vector = N(20,0)')
# Out:
# Text(0.5, 1.0, 'data = N(0,0), vector = N(20,0)')

# %%
plt.hist(Results)
plt.title('data = N(0,0), vector = N(10,0)')
# Out:
# Text(0.5, 1.0, 'data = N(0,0), vector = N(10,0)')

# %%
plt.hist(Results)
plt.title('data = N(0,0), vector = N(0,0)')
# Out:
# Text(0.5, 1.0, 'data = N(0,0), vector = N(0,0)')
